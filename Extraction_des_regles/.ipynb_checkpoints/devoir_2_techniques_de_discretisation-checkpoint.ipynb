# %% [markdown]
# ## DEVOIR 02:APPLICATION DES DIFFERENTES METHODES DE DISCRETISATION

# %%
import pandas as pd
import numpy as np
from sklearn.datasets import load_wine
from sklearn.preprocessing import KBinsDiscretizer
from sklearn.cluster import KMeans
from sklearn.preprocessing import KBinsDiscretizer
import pandas as pd
from sklearn.datasets import load_wine
from sklearn.feature_selection import mutual_info_classif
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.tree import DecisionTreeClassifier

# %%
# Charger le dataset Wine
data = load_wine()
df = pd.DataFrame(data.data, columns=data.feature_names)
df['target'] = data.target
print("Aperçu du dataset Wine:")
print(df.head(), "\n")
# Out:
# Aperçu du dataset Wine:
#    alcohol  malic_acid   ash  alcalinity_of_ash  magnesium  total_phenols  \
# 0    14.23        1.71  2.43               15.6      127.0           2.80
# 1    13.20        1.78  2.14               11.2      100.0           2.65
# 2    13.16        2.36  2.67               18.6      101.0           2.80
# 3    14.37        1.95  2.50               16.8      113.0           3.85
# 4    13.24        2.59  2.87               21.0      118.0           2.80
#
#    flavanoids  nonflavanoid_phenols  proanthocyanins  color_intensity   hue  \
# 0        3.06                  0.28             2.29             5.64  1.04
# 1        2.76                  0.26             1.28             4.38  1.05
# 2        3.24                  0.30             2.81             5.68  1.03
# 3        3.49                  0.24             2.18             7.80  0.86
# 4        2.69                  0.39             1.82             4.32  1.04
#
#    od280/od315_of_diluted_wines  proline  target
# 0                          3.92   1065.0       0
# 1                          3.40   1050.0       0
# 2                          3.17   1185.0       0
# 3                          3.45   1480.0       0
# 4                          2.93    735.0       0

# %%
# On choisit une variable continue à discrétiser, ex: "alcohol"
X = df[['alcohol']].values
y = df['target'].values

# %% [markdown]
# ### Méthode basée sur la discrétisation

# %% [markdown]
# ### Intervalles de largeur égales

# %% [markdown]
# #### Explication : ici,nous divisons la plage des valeurs en intervalles de meme longueur. Choississons k=3.Pour ce faire,nous allons calculer les bornes avec la formue suivante :Largeur=(max−min)/nombres d intervalles

# %% [markdown]
# #### k=3 est souvent utilisé si on sait qu’il y a environ 3 sous-groupes naturels dans la donnée (ici, le dataset Wine a 3 classes de vin).
#
# #### Donc le choix de k=3 est cohérent avec le nombre de classes réelles (target) du dataset.

# %%
# Variable choisie
col = 'alcohol'
values = df[col].values

# Paramètres
k = 3  # nombre d'intervalles
vmin, vmax = values.min(), values.max()

# Formule
width = (vmax - vmin) / k
bins = [vmin + i*width for i in range(k)] + [vmax]  # bornes des intervalles

# Discrétisation
df['alcohol_equal_width'] = pd.cut(values, bins=bins, labels=False, include_lowest=True)

# Affichage
print(f"Variable: {col}")
print(f"Valeur min = {vmin:.2f}, max = {vmax:.2f}")
print(f"Largeur d'intervalle = {width:.2f}")
print("\nBornes des intervalles :", [round(b, 2) for b in bins], "\n")

# Afficher chaque intervalle avec -∞ et +∞
print("Intervalles avec bornes infinies:")
for i in range(len(bins) - 1):
    gauche = bins[i]
    droite = bins[i+1]
    if i == 0:
        print(f"Intervalle {i} : [-∞, {droite:.2f})")
    elif i == len(bins) - 2:
        print(f"Intervalle {i} : [{gauche:.2f}, +∞]")
    else:
        print(f"Intervalle {i} : [{gauche:.2f}, {droite:.2f})")

print("\nAperçu (10 premières lignes):")
print(df[[col, 'alcohol_equal_width']].head(10))

# ANALYSE DES RÉSULTATS
print("\n" + "="*50)
print("ANALYSE DE LA DISCRÉTISATION")
print("="*50)

# 1. Distribution des observations par intervalle
print("\n1. Répartition des observations par intervalle:")
interval_counts = df['alcohol_equal_width'].value_counts().sort_index()
for interval, count in interval_counts.items():
    percentage = (count / len(df)) * 100
    print(f"Intervalle {interval}: {count} observations ({percentage:.1f}%)")

# 2. Statistiques descriptives par intervalle
print("\n2. Statistiques par intervalle:")
for i in range(k):
    mask = df['alcohol_equal_width'] == i
    original_values = df.loc[mask, col]
    print(f"\nIntervalle {i}:")
    print(f"  Nombre: {len(original_values)}")
    print(f"  Min: {original_values.min():.2f}")
    print(f"  Max: {original_values.max():.2f}")
    print(f"  Moyenne: {original_values.mean():.2f}")

# 3. Relation avec la variable cible
print("\n3. Relation avec la variable target:")
cross_tab = pd.crosstab(df['alcohol_equal_width'], df['target'])
print(cross_tab)

# VISUALISATIONS
plt.figure(figsize=(15, 8))

# Graphique 1: Distribution originale vs discrétisée
plt.subplot(2, 2, 1)
plt.hist(values, bins=20, alpha=0.7, color='skyblue', edgecolor='black')
plt.title('Distribution originale de alcohol')
plt.xlabel('Teneur en alcool')
plt.ylabel('Fréquence')

plt.subplot(2, 2, 2)
df['alcohol_equal_width'].value_counts().sort_index().plot(kind='bar', color='lightcoral')
plt.title('Distribution après discrétisation')
plt.xlabel('Intervalles')
plt.ylabel('Nombre d\'observations')
plt.xticks(rotation=0)

# Graphique 3: Boxplot par intervalle
plt.subplot(2, 2, 3)
sns.boxplot(x='alcohol_equal_width', y=col, data=df)
plt.title('Distribution de alcohol par intervalle')
plt.xlabel('Intervalle')
plt.ylabel('Teneur en alcool')

# Graphique 4: Relation avec la target (diagramme en barres groupées)
plt.subplot(2, 2, 4)
cross_tab.plot(kind='bar', ax=plt.gca())
plt.title('Répartition des classes par intervalle')
plt.xlabel('Intervalle')
plt.ylabel('Nombre d\'observations')
plt.legend(title='Classe', labels=['Classe 0', 'Classe 1', 'Classe 2'])
plt.xticks(rotation=0)

plt.tight_layout()
plt.show()

# EXPLICATION DES GRAPHIQUES
print("\n" + "="*50)
print("EXPLICATION DES GRAPHIQUES")
print("="*50)

print("\n1. BOÎTE À MOUSTACHES (Boxplot):")
print("   - La boîte représente les 50% centraux des données (Q1 à Q3)")
print("   - La ligne dans la boîte est la médiane")
print("   - Les 'moustaches' s'étendent jusqu'aux valeurs non aberrantes")
print("   - Les points au-delà des moustaches sont des valeurs aberrantes")
print("   - Ce graphique montre comment se répartissent les valeurs d'alcool dans chaque intervalle")

print("\n2. DIAGRAMME EN BARRES GROUPÉES:")
print("   - Montre le nombre d'observations de chaque classe (0, 1, 2) dans chaque intervalle")
print("   - Permet de voir si certaines classes sont surreprésentées dans certains intervalles")
print("   - Exemple: Si la classe 1 domine dans l'intervalle 2, cela signifie que les vins de classe 1")
print("     ont généralement une teneur en alcool dans cette plage")

# Création d'étiquettes avec bornes infinies pour une meilleure compréhension
labels = []
for i in range(len(bins) - 1):
    if i == 0:
        labels.append(f"]-∞, {bins[1]:.1f}[")
    elif i == len(bins) - 2:
        labels.append(f"[{bins[i]:.1f}, +∞[")
    else:
        labels.append(f"[{bins[i]:.1f}, {bins[i+1]:.1f}[")

print(f"\nIntervalles avec notation infinie:")
for i, label in enumerate(labels):
    count = (df['alcohol_equal_width'] == i).sum()
    print(f"Intervalle {i} {label}: {count} observations")
# Out:
# Variable: alcohol
# Valeur min = 11.03, max = 14.83
# Largeur d'intervalle = 1.27
#
# Bornes des intervalles : [np.float64(11.03), np.float64(12.3), np.float64(13.56), np.float64(14.83)]
#
# Intervalles avec bornes infinies:
# Intervalle 0 : [-∞, 12.30)
# Intervalle 1 : [12.30, 13.56)
# Intervalle 2 : [13.56, +∞]
#
# Aperçu (10 premières lignes):
#    alcohol  alcohol_equal_width
# 0    14.23                    2
# 1    13.20                    1
# 2    13.16                    1
# 3    14.37                    2
# 4    13.24                    1
# 5    14.20                    2
# 6    14.39                    2
# 7    14.06                    2
# 8    14.83                    2
# 9    13.86                    2
#
# ==================================================
# ANALYSE DE LA DISCRÉTISATION
# ==================================================
#
# 1. Répartition des observations par intervalle:
# Intervalle 0: 41 observations (23.0%)
# Intervalle 1: 86 observations (48.3%)
# Intervalle 2: 51 observations (28.7%)
#
# 2. Statistiques par intervalle:
#
# Intervalle 0:
#   Nombre: 41
#   Min: 11.03
#   Max: 12.29
#   Moyenne: 11.93
#
# Intervalle 1:
#   Nombre: 86
#   Min: 12.33
#   Max: 13.56
#   Moyenne: 12.93
#
# Intervalle 2:
#   Nombre: 51
#   Min: 13.58
#   Max: 14.83
#   Moyenne: 13.98
#
# 3. Relation avec la variable target:
# target                0   1   2
# alcohol_equal_width
# 0                     0  38   3
# 1                    21  31  34
# 2                    38   2  11
# ==================================================
# EXPLICATION DES GRAPHIQUES
# ==================================================
#
# 1. BOÎTE À MOUSTACHES (Boxplot):
#    - La boîte représente les 50% centraux des données (Q1 à Q3)
#    - La ligne dans la boîte est la médiane
#    - Les 'moustaches' s'étendent jusqu'aux valeurs non aberrantes
#    - Les points au-delà des moustaches sont des valeurs aberrantes
#    - Ce graphique montre comment se répartissent les valeurs d'alcool dans chaque intervalle
#
# 2. DIAGRAMME EN BARRES GROUPÉES:
#    - Montre le nombre d'observations de chaque classe (0, 1, 2) dans chaque intervalle
#    - Permet de voir si certaines classes sont surreprésentées dans certains intervalles
#    - Exemple: Si la classe 1 domine dans l'intervalle 2, cela signifie que les vins de classe 1
#      ont généralement une teneur en alcool dans cette plage
#
# Intervalles avec notation infinie:
# Intervalle 0 ]-∞, 12.3[: 41 observations
# Intervalle 1 [12.3, 13.6[: 86 observations
# Intervalle 2 [13.6, +∞[: 51 observations

# %% [markdown]
# ### Fréquences égales

# %% [markdown]
# #### Explication: ici chaque intervalle contient environ le meme nombres d instances.Pour ce faire,appliquons la formule taille_intervalle=nombre d obserations/nombre d intervalles

# %%
import pandas as pd
import numpy as np
from sklearn.datasets import load_wine
import matplotlib.pyplot as plt
import seaborn as sns

# Charger les données
data = load_wine()
df = pd.DataFrame(data.data, columns=data.feature_names)
df['target'] = data.target

print("DÉMARRAGE DE LA VÉRIFICATION MANUELLE")
print("="*60)

# Variable choisie
col = 'alcohol'
values = df[col].values
n_obs = len(values)

print(f"Nombre total d'observations: {n_obs}")

# 1. TRI DES VALEURS (du plus petit au plus grand)
print("\n1. TRI DES VALEURS:")
sorted_values = np.sort(values)
print(f"Valeurs triées (5 premières): {sorted_values[:5].round(2)}")
print(f"Valeurs triées (5 dernières): {sorted_values[-5:].round(2)}")

# 2. CALCUL MANUEL DES BORNES
print("\n2. CALCUL MANUEL DES BORNES:")
k = 3  # nombre d'intervalles

# Calcul correct des indices
indices_quantiles = [int(n_obs * i/k) for i in range(k+1)]
# Ajuster le dernier indice pour qu'il soit dans les bornes
indices_quantiles[-1] = n_obs - 1

print(f"Indices des quantiles: {indices_quantiles}")

# Bornes manuelles
bornes_manuelles = [sorted_values[i] for i in indices_quantiles]
print(f"Bornes manuelles: {[round(b, 2) for b in bornes_manuelles]}")

# 3. COMPTAGE MANUEL PAR INTERVALLE
print("\n3. COMPTAGE MANUEL PAR INTERVALLE:")
comptage_manuel = []
intervalles_manuels = np.zeros(n_obs)  # Pour stocker les labels d'intervalles

for i in range(k):
    if i == 0:
        # Premier intervalle : [borne_inf, borne_sup]
        mask = (values >= bornes_manuelles[i]) & (values <= bornes_manuelles[i+1])
    else:
        # Intervalles suivants : (borne_inf, borne_sup]
        mask = (values > bornes_manuelles[i]) & (values <= bornes_manuelles[i+1])
    
    count = np.sum(mask)
    pourcentage = (count / n_obs) * 100
    comptage_manuel.append(count)
    
    # Stocker les labels d'intervalles
    intervalles_manuels[mask] = i
    
    print(f"Intervalle {i}:")
    if i == 0:
        print(f"  Plage: [{bornes_manuelles[i]:.2f}, {bornes_manuelles[i+1]:.2f}]")
    else:
        print(f"  Plage: ({bornes_manuelles[i]:.2f}, {bornes_manuelles[i+1]:.2f}]")
    print(f"  → {count} observations ({pourcentage:.1f}%)")

print(f"\nTotal vérifié: {sum(comptage_manuel)} observations")

# 4. AJOUT AU DATAFRAME
df['alcohol_equal_freq_manuel'] = intervalles_manuels

# 5. ANALYSE DÉTAILLÉE DE CHAQUE INTERVALLE
print("\n4. ANALYSE DÉTAILLÉE PAR INTERVALLE:")
for i in range(k):
    print(f"\n--- INTERVALLE {i} ---")
    
    mask_intervalle = (df['alcohol_equal_freq_manuel'] == i)
    donnees_intervalle = df.loc[mask_intervalle, col]
    
    if i == 0:
        print(f"Plage: [{bornes_manuelles[i]:.2f}, {bornes_manuelles[i+1]:.2f}]")
    else:
        print(f"Plage: ({bornes_manuelles[i]:.2f}, {bornes_manuelles[i+1]:.2f}]")
        
    print(f"Nombre: {len(donnees_intervalle)}")
    print(f"Min: {donnees_intervalle.min():.2f}")
    print(f"Max: {donnees_intervalle.max():.2f}")
    print(f"Moyenne: {donnees_intervalle.mean():.2f}")
    print(f"Médiane: {np.median(donnees_intervalle):.2f}")
    print(f"Écart-type: {donnees_intervalle.std():.2f}")

# 6. RELATION AVEC LA VARIABLE CIBLE
print("\n5. RELATION AVEC LA VARIABLE TARGET:")
cross_tab = pd.crosstab(df['alcohol_equal_freq_manuel'], df['target'])
print(cross_tab)

# 7. VISUALISATIONS
plt.figure(figsize=(15, 12))

# Graphique 1: Distribution originale avec bornes
plt.subplot(2, 2, 1)
plt.hist(values, bins=20, alpha=0.7, color='lightblue', edgecolor='black', label='Distribution')
for i, borne in enumerate(bornes_manuelles):
    plt.axvline(x=borne, color='red', linestyle='--', alpha=0.7, 
                label='Bornes' if i == 0 else "")
plt.title('Distribution originale de alcohol\navec bornes de discrétisation')
plt.xlabel('Teneur en alcool')
plt.ylabel('Fréquence')
plt.legend()

# Graphique 2: Distribution après discrétisation
plt.subplot(2, 2, 2)
df['alcohol_equal_freq_manuel'].value_counts().sort_index().plot(kind='bar', color='lightgreen')
plt.title('Distribution après discrétisation\n(fréquence égale)')
plt.xlabel('Intervalles')
plt.ylabel('Nombre d\'observations')
plt.xticks(rotation=0)

# Graphique 3: Boîte à moustaches par intervalle
plt.subplot(2, 2, 3)
sns.boxplot(x='alcohol_equal_freq_manuel', y='alcohol', data=df)
plt.title('Boîtes à moustaches par intervalle')
plt.xlabel('Intervalle')
plt.ylabel('Teneur en alcool')

# Graphique 4: Relation avec la target
plt.subplot(2, 2, 4)
cross_tab.plot(kind='bar', ax=plt.gca())
plt.title('Répartition des classes par intervalle')
plt.xlabel('Intervalle')
plt.ylabel('Nombre d\'observations')
plt.legend(title='Classe', labels=['Classe 0', 'Classe 1', 'Classe 2'])
plt.xticks(rotation=0)

plt.tight_layout()
plt.show()

# 8. ANALYSE DES BOÎTES À MOUSTACHES
print("\n6. ANALYSE DES BOÎTES À MOUSTACHES:")
for i in range(k):
    print(f"\n--- BOÎTE À MOUSTACHES - INTERVALLE {i} ---")
    
    mask_intervalle = (df['alcohol_equal_freq_manuel'] == i)
    donnees_intervalle = df.loc[mask_intervalle, col]
    
    Q1 = np.percentile(donnees_intervalle, 25)
    Q3 = np.percentile(donnees_intervalle, 75)
    IQR = Q3 - Q1
    borne_inf = Q1 - 1.5 * IQR
    borne_sup = Q3 + 1.5 * IQR
    valeurs_aberrantes = donnees_intervalle[(donnees_intervalle < borne_inf) | (donnees_intervalle > borne_sup)]
    
    print(f"Médiane: {np.median(donnees_intervalle):.2f}")
    print(f"Q1 (25%): {Q1:.2f}")
    print(f"Q3 (75%): {Q3:.2f}")
    print(f"IQR: {IQR:.2f}")
    print(f"Bornes aberrantes: [{borne_inf:.2f}, {borne_sup:.2f}]")
    print(f"Valeurs aberrantes: {len(valeurs_aberrantes)}")

# 9. CRÉATION D'ÉTIQUETTES DESCRIPTIVES
print("\n7. INTERVALLES DESCRIPTIFS:")
labels_desc = []
for i in range(len(bornes_manuelles) - 1):
    if i == 0:
        labels_desc.append(f"Faible alcool [-∞, {bornes_manuelles[1]:.1f}]")
    elif i == len(bornes_manuelles) - 2:
        labels_desc.append(f"Fort alcool [{bornes_manuelles[i]:.1f}, +∞]")
    else:
        labels_desc.append(f"Alcool moyen [{bornes_manuelles[i]:.1f}, {bornes_manuelles[i+1]:.1f}]")

print("Intervalles descriptifs:")
for i, label in enumerate(labels_desc):
    count = (df['alcohol_equal_freq_manuel'] == i).sum()
    min_val = df[df['alcohol_equal_freq_manuel'] == i]['alcohol'].min()
    max_val = df[df['alcohol_equal_freq_manuel'] == i]['alcohol'].max()
    print(f"Intervalle {i}: {label}")
    print(f"  → {count} observations, plage réelle: [{min_val:.1f}, {max_val:.1f}]")

# 10. SYNTHÈSE
print("\n" + "="*60)
print("SYNTHÈSE DE LA DISCRÉTISATION PAR FRÉQUENCES ÉGALES")
print("="*60)

print("✓ Méthode appliquée: Fréquences égales (méthode manuelle)")
print("✓ Principe: Les données sont triées et divisées en intervalles")
print("✓ Objectif: Chaque intervalle contient ≈ même nombre d'observations")
print(f"✓ Résultat: {comptage_manuel} observations par intervalle")
print(f"✓ Écart maximum: {max(comptage_manuel) - min(comptage_manuel)} observation(s)")

print("\nInterprétation des boîtes à moustaches:")
print("- La boîte représente les 50% centraux des données (Q1 à Q3)")
print("- La ligne dans la boîte est la médiane")
print("- Les moustaches s'étendent jusqu'aux valeurs non aberrantes")
print("- Les points isolés sont des valeurs aberrantes")

print("\nLa discrétisation par fréquences égales a été réalisée avec succès!")
# Out:
# DÉMARRAGE DE LA VÉRIFICATION MANUELLE
# ============================================================
# Nombre total d'observations: 178
#
# 1. TRI DES VALEURS:
# Valeurs triées (5 premières): [11.03 11.41 11.45 11.46 11.56]
# Valeurs triées (5 dernières): [14.38 14.38 14.39 14.75 14.83]
#
# 2. CALCUL MANUEL DES BORNES:
# Indices des quantiles: [0, 59, 118, 177]
# Bornes manuelles: [np.float64(11.03), np.float64(12.52), np.float64(13.48), np.float64(14.83)]
#
# 3. COMPTAGE MANUEL PAR INTERVALLE:
# Intervalle 0:
#   Plage: [11.03, 12.52]
#   → 60 observations (33.7%)
# Intervalle 1:
#   Plage: (12.52, 13.48]
#   → 59 observations (33.1%)
# Intervalle 2:
#   Plage: (13.48, 14.83]
#   → 59 observations (33.1%)
#
# Total vérifié: 178 observations
#
# 4. ANALYSE DÉTAILLÉE PAR INTERVALLE:
#
# --- INTERVALLE 0 ---
# Plage: [11.03, 12.52]
# Nombre: 60
# Min: 11.03
# Max: 12.52
# Moyenne: 12.08
# Médiane: 12.16
# Écart-type: 0.33
#
# --- INTERVALLE 1 ---
# Plage: (12.52, 13.48]
# Nombre: 59
# Min: 12.53
# Max: 13.48
# Moyenne: 13.03
# Médiane: 13.05
# Écart-type: 0.26
#
# --- INTERVALLE 2 ---
# Plage: (13.48, 14.83]
# Nombre: 59
# Min: 13.49
# Max: 14.83
# Moyenne: 13.91
# Médiane: 13.84
# Écart-type: 0.32
#
# 5. RELATION AVEC LA VARIABLE TARGET:
# target                      0   1   2
# alcohol_equal_freq_manuel
# 0.0                         0  54   6
# 1.0                        17  14  28
# 2.0                        42   3  14
# 6. ANALYSE DES BOÎTES À MOUSTACHES:
#
# --- BOÎTE À MOUSTACHES - INTERVALLE 0 ---
# Médiane: 12.16
# Q1 (25%): 11.84
# Q3 (75%): 12.36
# IQR: 0.53
# Bornes aberrantes: [11.04, 13.15]
# Valeurs aberrantes: 1
#
# --- BOÎTE À MOUSTACHES - INTERVALLE 1 ---
# Médiane: 13.05
# Q1 (25%): 12.82
# Q3 (75%): 13.24
# IQR: 0.42
# Bornes aberrantes: [12.18, 13.88]
# Valeurs aberrantes: 0
#
# --- BOÎTE À MOUSTACHES - INTERVALLE 2 ---
# Médiane: 13.84
# Q1 (25%): 13.68
# Q3 (75%): 14.14
# IQR: 0.46
# Bornes aberrantes: [12.99, 14.84]
# Valeurs aberrantes: 0
#
# 7. INTERVALLES DESCRIPTIFS:
# Intervalles descriptifs:
# Intervalle 0: Faible alcool [-∞, 12.5]
#   → 60 observations, plage réelle: [11.0, 12.5]
# Intervalle 1: Alcool moyen [12.5, 13.5]
#   → 59 observations, plage réelle: [12.5, 13.5]
# Intervalle 2: Fort alcool [13.5, +∞]
#   → 59 observations, plage réelle: [13.5, 14.8]
#
# ============================================================
# SYNTHÈSE DE LA DISCRÉTISATION PAR FRÉQUENCES ÉGALES
# ============================================================
# ✓ Méthode appliquée: Fréquences égales (méthode manuelle)
# ✓ Principe: Les données sont triées et divisées en intervalles
# ✓ Objectif: Chaque intervalle contient ≈ même nombre d'observations
# ✓ Résultat: [np.int64(60), np.int64(59), np.int64(59)] observations par intervalle
# ✓ Écart maximum: 1 observation(s)
#
# Interprétation des boîtes à moustaches:
# - La boîte représente les 50% centraux des données (Q1 à Q3)
# - La ligne dans la boîte est la médiane
# - Les moustaches s'étendent jusqu'aux valeurs non aberrantes
# - Les points isolés sont des valeurs aberrantes
#
# La discrétisation par fréquences égales a été réalisée avec succès!

# %% [markdown]
# ### Entropie

# %% [markdown]
# #### Explication:ici,nous minimise l'entropie de classe dans chaque intervalle

# %%
# Variable choisie
X = df[['alcohol']]
y = df['target']

# Méthode par entropie utilisant un arbre de décision
tree_model = DecisionTreeClassifier(
    criterion='entropy',
    max_leaf_nodes=4,  # k+1 feuilles pour k intervalles
    min_samples_leaf=5,
    random_state=42
)

# Ajuster l'arbre sur la variable continue
tree_model.fit(X, y)

# Récupérer les seuils de coupure (triés et uniques)
seuils = np.unique(tree_model.tree_.threshold[tree_model.tree_.threshold != -2])
seuils = sorted(seuils[seuils != -2])  # Enlever les valeurs par défaut

print("Seuils optimaux trouvés par l'arbre de décision (entropie):", [round(s, 2) for s in seuils])

# Discrétiser selon ces seuils
df['alcohol_entropy'] = np.digitize(X.values.ravel(), bins=seuils)

# Afficher les intervalles avec -∞ et +∞
print("\nIntervalles avec bornes infinies:")
for i in range(len(seuils) + 1):
    if i == 0:
        print(f"Intervalle {i} : [-∞, {seuils[i]:.2f})")
    elif i == len(seuils):
        print(f"Intervalle {i} : [{seuils[i-1]:.2f}, +∞]")
    else:
        print(f"Intervalle {i} : [{seuils[i-1]:.2f}, {seuils[i]:.2f})")

# Évaluer la pertinence avec l'information mutuelle
mi = mutual_info_classif(df[['alcohol_entropy']], y, discrete_features=True)
print(f"\nInformation mutuelle avec la cible: {mi[0]:.4f}")

# ANALYSE DES RÉSULTATS
print("\n" + "="*50)
print("ANALYSE DE LA DISCRÉTISATION PAR ENTROPIE")
print("="*50)

# 1. Distribution des observations par intervalle
print("\n1. Répartition des observations par intervalle:")
interval_counts = df['alcohol_entropy'].value_counts().sort_index()
for interval, count in interval_counts.items():
    percentage = (count / len(df)) * 100
    print(f"Intervalle {interval}: {count} observations ({percentage:.1f}%)")

# 2. Relation avec la variable cible
print("\n2. Relation avec la variable target:")
cross_tab = pd.crosstab(df['alcohol_entropy'], df['target'])
print(cross_tab)

# 3. Pureté des intervalles
print("\n3. Pureté des intervalles (classe majoritaire):")
for i in range(len(seuils) + 1):
    mask = df['alcohol_entropy'] == i
    if mask.sum() > 0:
        target_dist = df.loc[mask, 'target'].value_counts()
        major_class = target_dist.index[0]
        major_percent = (target_dist.iloc[0] / mask.sum()) * 100
        print(f"Intervalle {i}: Classe {major_class} ({major_percent:.1f}%) - {mask.sum()} observations")

# VISUALISATIONS
plt.figure(figsize=(15, 10))

# Graphique 1: Distribution originale avec seuils
plt.subplot(2, 2, 1)
plt.hist(df['alcohol'], bins=20, alpha=0.7, color='skyblue', edgecolor='black')
for seuil in seuils:
    plt.axvline(x=seuil, color='red', linestyle='--', alpha=0.7, label='Seuils optimaux' if seuil == seuils[0] else "")
plt.title('Distribution originale avec seuils optimaux\n(méthode entropie)')
plt.xlabel('Teneur en alcool')
plt.ylabel('Fréquence')
plt.legend()

# Graphique 2: Distribution après discrétisation
plt.subplot(2, 2, 2)
df['alcohol_entropy'].value_counts().sort_index().plot(kind='bar', color='orange')
plt.title('Distribution après discrétisation\n(entropie)')
plt.xlabel('Intervalles')
plt.ylabel('Nombre d\'observations')
plt.xticks(rotation=0)

# Graphique 3: Boxplot par intervalle
plt.subplot(2, 2, 3)
sns.boxplot(x='alcohol_entropy', y='alcohol', data=df)
plt.title('Distribution de alcohol par intervalle')
plt.xlabel('Intervalle')
plt.ylabel('Teneur en alcool')

# Graphique 4: Relation avec la target
plt.subplot(2, 2, 4)
cross_tab.plot(kind='bar', ax=plt.gca())
plt.title('Répartition des classes par intervalle')
plt.xlabel('Intervalle')
plt.ylabel('Nombre d\'observations')
plt.legend(title='Classe', labels=['Classe 0', 'Classe 1', 'Classe 2'])
plt.xticks(rotation=0)

plt.tight_layout()
plt.show()

# COMPARAISON AVEC LES AUTRES MÉTHODES
print("\n" + "="*50)
print("COMPARAISON DES MÉTHODES")
print("="*50)

print("Largeur égale - Information mutuelle:", 
      mutual_info_classif(df[['alcohol_equal_width']], y, discrete_features=True)[0])
print("Fréquence égale - Information mutuelle:", 
      mutual_info_classif(df[['alcohol_equal_freq']], y, discrete_features=True)[0])
print("Entropie - Information mutuelle:", mi[0])

print("\nAperçu des différentes discrétisations (10 premières lignes):")
print(df[['alcohol', 'alcohol_equal_width', 'alcohol_equal_freq', 'alcohol_entropy']].head(10))
# Out:
# Seuils optimaux trouvés par l'arbre de décision (entropie): [np.float64(12.18), np.float64(12.78), np.float64(13.72)]
#
# Intervalles avec bornes infinies:
# Intervalle 0 : [-∞, 12.18)
# Intervalle 1 : [12.18, 12.78)
# Intervalle 2 : [12.78, 13.72)
# Intervalle 3 : [13.72, +∞]
#
# Information mutuelle avec la cible: 0.4670
#
# ==================================================
# ANALYSE DE LA DISCRÉTISATION PAR ENTROPIE
# ==================================================
#
# 1. Répartition des observations par intervalle:
# Intervalle 0: 31 observations (17.4%)
# Intervalle 1: 42 observations (23.6%)
# Intervalle 2: 64 observations (36.0%)
# Intervalle 3: 41 observations (23.0%)
#
# 2. Relation avec la variable target:
# target            0   1   2
# alcohol_entropy
# 0                 0  31   0
# 1                 0  31  11
# 2                26   8  30
# 3                33   1   7
#
# 3. Pureté des intervalles (classe majoritaire):
# Intervalle 0: Classe 1 (100.0%) - 31 observations
# Intervalle 1: Classe 1 (73.8%) - 42 observations
# Intervalle 2: Classe 2 (46.9%) - 64 observations
# Intervalle 3: Classe 0 (80.5%) - 41 observations
# ==================================================
# COMPARAISON DES MÉTHODES
# ==================================================
# Largeur égale - Information mutuelle: 0.31045940012199513
# Fréquence égale - Information mutuelle: 0.37789395784729063
# Entropie - Information mutuelle: 0.4670015877174661
#
# Aperçu des différentes discrétisations (10 premières lignes):
#    alcohol  alcohol_equal_width  alcohol_equal_freq  alcohol_entropy
# 0    14.23                    2                 2.0                3
# 1    13.20                    1                 1.0                2
# 2    13.16                    1                 1.0                2
# 3    14.37                    2                 2.0                3
# 4    13.24                    1                 1.0                2
# 5    14.20                    2                 2.0                3
# 6    14.39                    2                 2.0                3
# 7    14.06                    2                 2.0                3
# 8    14.83                    2                 2.0                3
# 9    13.86                    2                 2.0                3

# %% [markdown]
# Principe : L'arbre de décision trouve les coupures qui maximisent le gain d'information (minimisent l'entropie) pour séparer les classes.
#
# Avantages :
#
#     Les intervalles sont optimisés pour discriminer les classes cibles
#
#     Meilleure séparation entre les groupes
#
#     Plus d'information préservée pour la prédiction
# La méthode par entropie devrait donner une information mutuelle plus élevée que les autres méthodes car elle est optimisée pour la classification !

# %% [markdown]
# ### Methode basée sur le clustering

# %% [markdown]
# #### Explication: On applique un algorithme de clustering sur les valeurs continues, puis on affecte chaque cluster à un intervalle.
#
# #### Exemple : appliquer k-means sur la variable alcohol avec k=3 → 3 groupes naturels : faible, moyen, fort.

# %%
# On récupère la colonne alcohol comme array numpy
X = df['alcohol'].values.reshape(-1, 1)

# KMeans avec 3 clusters
kmeans = KMeans(n_clusters=3, random_state=0, n_init=10)
clusters = kmeans.fit_predict(X)
df['alcohol_clusters'] = clusters

# Centres des clusters
centres = np.sort(kmeans.cluster_centers_.flatten())

print("Centres des clusters (KMeans):")
for i, c in enumerate(centres):
    print(f"Cluster {i} : centre = {c:.2f}")

# Déterminer les bornes des intervalles (à partir des centres triés)
# Les coupures sont à mi-chemin entre deux centres
bornes = []
for i in range(len(centres)-1):
    borne = (centres[i] + centres[i+1]) / 2
    bornes.append(borne)

print("\nBornes estimées entre clusters :", [round(b, 2) for b in bornes], "\n")

# Afficher les intervalles de chaque cluster avec -∞ et +∞
print("Intervalles avec bornes infinies:")
for i in range(len(centres)):
    if i == 0:
        print(f"Intervalle {i} : [-∞, {bornes[i]:.2f})")
    elif i == len(centres)-1:
        print(f"Intervalle {i} : [{bornes[i-1]:.2f}, +∞]")
    else:
        print(f"Intervalle {i} : [{bornes[i-1]:.2f}, {bornes[i]:.2f})")

# ANALYSE DES RÉSULTATS
print("\n" + "="*50)
print("ANALYSE DE LA DISCRÉTISATION PAR CLUSTERING")
print("="*50)

# 1. Distribution des observations par cluster
print("\n1. Répartition des observations par cluster:")
cluster_counts = df['alcohol_clusters'].value_counts().sort_index()
for cluster, count in cluster_counts.items():
    percentage = (count / len(df)) * 100
    print(f"Cluster {cluster}: {count} observations ({percentage:.1f}%)")

# 2. Statistiques descriptives par cluster
print("\n2. Statistiques par cluster:")
for i in range(3):
    mask = df['alcohol_clusters'] == i
    original_values = df.loc[mask, 'alcohol']
    print(f"\nCluster {i} (centre: {centres[i]:.2f}):")
    print(f"  Nombre: {len(original_values)}")
    print(f"  Min: {original_values.min():.2f}")
    print(f"  Max: {original_values.max():.2f}")
    print(f"  Moyenne: {original_values.mean():.2f}")
    print(f"  Écart-type: {original_values.std():.2f}")

# 3. Relation avec la variable cible
print("\n3. Relation avec la variable target:")
cross_tab = pd.crosstab(df['alcohol_clusters'], df['target'])
print(cross_tab)

# 4. Évaluation de la qualité du clustering
from sklearn.metrics import silhouette_score

silhouette_avg = silhouette_score(X, clusters)
print(f"\n4. Score de silhouette: {silhouette_avg:.4f}")
print("   (Plus proche de 1 = meilleure séparation des clusters)")

# VISUALISATIONS
plt.figure(figsize=(15, 10))

# Graphique 1: Distribution originale avec centres des clusters
plt.subplot(2, 2, 1)
plt.hist(df['alcohol'], bins=20, alpha=0.7, color='skyblue', edgecolor='black')
for centre in centres:
    plt.axvline(x=centre, color='red', linestyle='-', alpha=0.8, linewidth=2, label='Centres clusters' if centre == centres[0] else "")
for borne in bornes:
    plt.axvline(x=borne, color='orange', linestyle='--', alpha=0.6, label='Bornes' if borne == bornes[0] else "")
plt.title('Distribution originale avec centres et bornes\n(méthode clustering)')
plt.xlabel('Teneur en alcool')
plt.ylabel('Fréquence')
plt.legend()

# Graphique 2: Distribution après clustering
plt.subplot(2, 2, 2)
df['alcohol_clusters'].value_counts().sort_index().plot(kind='bar', color=['lightcoral', 'lightgreen', 'lightblue'])
plt.title('Distribution après clustering')
plt.xlabel('Clusters')
plt.ylabel('Nombre d\'observations')
plt.xticks(rotation=0)

# Graphique 3: Boxplot par cluster
plt.subplot(2, 2, 3)
sns.boxplot(x='alcohol_clusters', y='alcohol', data=df)
for i, centre in enumerate(centres):
    plt.scatter(i, centre, color='red', s=100, zorder=5, label='Centre du cluster' if i == 0 else "")
plt.title('Distribution de alcohol par cluster\n(● = centre du cluster)')
plt.xlabel('Cluster')
plt.ylabel('Teneur en alcool')
plt.legend()

# Graphique 4: Relation avec la target
plt.subplot(2, 2, 4)
cross_tab.plot(kind='bar', ax=plt.gca())
plt.title('Répartition des classes par cluster')
plt.xlabel('Cluster')
plt.ylabel('Nombre d\'observations')
plt.legend(title='Classe', labels=['Classe 0', 'Classe 1', 'Classe 2'])
plt.xticks(rotation=0)

plt.tight_layout()
plt.show()

# COMPARAISON AVEC LES AUTRES MÉTHODES
print("\n" + "="*50)
print("COMPARAISON DES MÉTHODES")
print("="*50)

methods = ['alcohol_equal_width', 'alcohol_equal_freq', 'alcohol_entropy', 'alcohol_clusters']
method_names = ['Largeur égale', 'Fréquence égale', 'Entropie', 'Clustering']

print("Information mutuelle avec la cible:")
for method, name in zip(methods, method_names):
    if method in df.columns:
        mi = mutual_info_classif(df[[method]], y, discrete_features=True)[0]
        print(f"  {name}: {mi:.4f}")

# AFFICHAGE SYNTHÉTIQUE
print("\n" + "="*50)
print("SYNTHÈSE DES INTERVALLES - CLUSTERING")
print("="*50)

# Créer des étiquettes descriptives basées sur les centres
labels_clusters = []
for i in range(len(centres)):
    if centres[i] < 13:
        niveau = "Faible"
    elif centres[i] < 13.5:
        niveau = "Moyen"
    else:
        niveau = "Élevé"
    labels_clusters.append(f"{niveau} alcool")

print("\nCaractérisation des clusters:")
for i in range(len(centres)):
    mask = df['alcohol_clusters'] == i
    count = mask.sum()
    mean_alc = df.loc[mask, 'alcohol'].mean()
    major_class = df.loc[mask, 'target'].value_counts().index[0]
    print(f"Cluster {i} ({labels_clusters[i]}):")
    print(f"  Centre: {centres[i]:.2f}, Moyenne réelle: {mean_alc:.2f}")
    print(f"  {count} observations, Classe majoritaire: {major_class}")

print("\nAperçu des différentes discrétisations (10 premières lignes):")
print(df[['alcohol', 'alcohol_equal_width', 'alcohol_equal_freq', 'alcohol_entropy', 'alcohol_clusters']].head(10))
# Out:
# Centres des clusters (KMeans):
# Cluster 0 : centre = 12.09
# Cluster 1 : centre = 13.02
# Cluster 2 : centre = 13.90
#
# Bornes estimées entre clusters : [np.float64(12.55), np.float64(13.46)]
#
# Intervalles avec bornes infinies:
# Intervalle 0 : [-∞, 12.55)
# Intervalle 1 : [12.55, 13.46)
# Intervalle 2 : [13.46, +∞]
#
# ==================================================
# ANALYSE DE LA DISCRÉTISATION PAR CLUSTERING
# ==================================================
#
# 1. Répartition des observations par cluster:
# Cluster 0: 61 observations (34.3%)
# Cluster 1: 61 observations (34.3%)
# Cluster 2: 56 observations (31.5%)
#
# 2. Statistiques par cluster:
#
# Cluster 0 (centre: 12.09):
#   Nombre: 61
#   Min: 11.03
#   Max: 12.53
#   Moyenne: 12.09
#   Écart-type: 0.34
#
# Cluster 1 (centre: 13.02):
#   Nombre: 61
#   Min: 13.48
#   Max: 14.83
#   Moyenne: 13.90
#   Écart-type: 0.32
#
# Cluster 2 (centre: 13.90):
#   Nombre: 56
#   Min: 12.58
#   Max: 13.45
#   Moyenne: 13.02
#   Écart-type: 0.25
#
# 3. Relation avec la variable target:
# target             0   1   2
# alcohol_clusters
# 0                  0  54   7
# 1                 43   3  15
# 2                 16  14  26
#
# 4. Score de silhouette: 0.5582
#    (Plus proche de 1 = meilleure séparation des clusters)
# ==================================================
# COMPARAISON DES MÉTHODES
# ==================================================
# Information mutuelle avec la cible:
#   Largeur égale: 0.3105
#   Fréquence égale: 0.3779
#   Entropie: 0.4670
#   Clustering: 0.3768
#
# ==================================================
# SYNTHÈSE DES INTERVALLES - CLUSTERING
# ==================================================
#
# Caractérisation des clusters:
# Cluster 0 (Faible alcool):
#   Centre: 12.09, Moyenne réelle: 12.09
#   61 observations, Classe majoritaire: 1
# Cluster 1 (Moyen alcool):
#   Centre: 13.02, Moyenne réelle: 13.90
#   61 observations, Classe majoritaire: 0
# Cluster 2 (Élevé alcool):
#   Centre: 13.90, Moyenne réelle: 13.02
#   56 observations, Classe majoritaire: 2
#
# Aperçu des différentes discrétisations (10 premières lignes):
#    alcohol  alcohol_equal_width  alcohol_equal_freq  alcohol_entropy  \
# 0    14.23                    2                 2.0                3
# 1    13.20                    1                 1.0                2
# 2    13.16                    1                 1.0                2
# 3    14.37                    2                 2.0                3
# 4    13.24                    1                 1.0                2
# 5    14.20                    2                 2.0                3
# 6    14.39                    2                 2.0                3
# 7    14.06                    2                 2.0                3
# 8    14.83                    2                 2.0                3
# 9    13.86                    2                 2.0                3
#
#    alcohol_clusters
# 0                 1
# 1                 2
# 2                 2
# 3                 1
# 4                 2
# 5                 1
# 6                 1
# 7                 1
# 8                 1
# 9                 1

# %% [markdown]
# Principe :
#
#     K-means groupe les données en clusters basés sur la similarité
#
#     Les centres des clusters déterminent les coupures naturelles
#
#     Les bornes sont à mi-distance entre les centres
#
# Avantages :
#
#     Trouve des regroupements naturels dans les données
#
#     Prend en compte la densité de distribution
#
#     Meilleur pour les distributions non uniformes

# %% [markdown]
# #### En résumé

# %% [markdown]
# Largeur égale	Divise en intervalles de même amplitude
#
# Fréquence égale	Divise en intervalles avec même nombre d'observations
#
# Entropie	Optimise les coupures pour séparer les classes
#
# Clustering	Trouve des groupes naturels dans les données

# %% [markdown]
# ### APPLICATION DE APRIORI A WINE

# %%
from mlxtend.frequent_patterns import apriori, association_rules
from mlxtend.preprocessing import TransactionEncoder


# 1. Préparation des données pour Apriori
print("PRÉPARATION DES DONNÉES POUR APRIORI")
print("="*50)

# Sélectionner les variables à discrétiser pour l'analyse associative
variables = ['alcohol', 'malic_acid', 'ash', 'magnesium', 'total_phenols', 'flavanoids']

# Discrétiser chaque variable en 3 catégories (faible, moyen, élevé)
df_apriori = df[['target']].copy()  # Commencer avec la target

for var in variables:
    # Utiliser la discrétisation par fréquence égale
    df_apriori[f'{var}_cat'] = pd.qcut(df[var], q=3, labels=[f'{var}_faible', f'{var}_moyen', f'{var}_élevé'])

# Ajouter aussi la variable target discrétisée
df_apriori['target_cat'] = df['target'].map({0: 'classe_0', 1: 'classe_1', 2: 'classe_2'})

print("Données après discrétisation :")
print(df_apriori.head())
print(f"\nShape: {df_apriori.shape}")

# 2. Conversion en format transactions
print("\n" + "="*50)
print("CONVERSION EN FORMAT TRANSACTIONS")
print("="*50)

# Créer les transactions (chaque ligne = un vin avec ses caractéristiques)
transactions = []
for i in range(len(df_apriori)):
    transaction = []
    for col in df_apriori.columns:
        if col != 'target':  # Exclure la target originale
            transaction.append(df_apriori.iloc[i][col])
    transactions.append(transaction)

print(f"Nombre de transactions: {len(transactions)}")
print("\nExemple de transaction (premier vin):")
print(transactions[0])

# 3. Encodage one-hot pour Apriori
print("\n" + "="*50)
print("ENCODAGE ONE-HOT")
print("="*50)

te = TransactionEncoder()
te_ary = te.fit(transactions).transform(transactions)
df_encoded = pd.DataFrame(te_ary, columns=te.columns_)

print(f"Shape encodé: {df_encoded.shape}")
print(f"Nombre d'items: {len(te.columns_)}")
print("\nColonnes (items):")
print(te.columns_)

# 4. Application de l'algorithme Apriori
print("\n" + "="*50)
print("APPLICATION APRIORI")
print("="*50)

# Trouver les itemsets fréquents avec support minimum
min_support = 0.2  # 20% des transactions
frequent_itemsets = apriori(df_encoded, min_support=min_support, use_colnames=True)

print(f"Itemsets fréquents (support ≥ {min_support}): {len(frequent_itemsets)}")
print("\nTop 10 itemsets les plus fréquents:")
frequent_itemsets['length'] = frequent_itemsets['itemsets'].apply(lambda x: len(x))
print(frequent_itemsets.sort_values('support', ascending=False).head(10))

# 5. Génération des règles d'association
print("\n" + "="*50)
print("RÈGLES D'ASSOCIATION")
print("="*50)

# Générer les règles avec différents seuils
rules = association_rules(frequent_itemsets, metric="confidence", min_threshold=0.6)

print(f"Nombre de règles générées: {len(rules)}")

if len(rules) > 0:
    print("\nTop 10 règles par confidence:")
    rules_sorted = rules.sort_values('confidence', ascending=False).head(10)
    
    # Afficher les règles de manière lisible
    for idx, rule in rules_sorted.iterrows():
        antecedents = list(rule['antecedents'])
        consequents = list(rule['consequents'])
        print(f"Règle: {antecedents} → {consequents}")
        print(f"  Support: {rule['support']:.3f}, Confidence: {rule['confidence']:.3f}, Lift: {rule['lift']:.3f}")
        print()
else:
    print("Aucune règle trouvée avec les paramètres actuels.")

# 6. Analyse spécifique par classe de vin
print("\n" + "="*50)
print("ANALYSE PAR CLASSE DE VIN")
print("="*50)

# Analyser les règles pour chaque classe
for classe in ['classe_0', 'classe_1', 'classe_2']:
    print(f"\n--- RÈGLES POUR LA {classe.upper()} ---")
    
    # Filtrer les règles où la conséquence est la classe
    class_rules = rules[rules['consequents'].apply(lambda x: classe in x)]
    
    if len(class_rules) > 0:
        print(f"Nombre de règles: {len(class_rules)}")
        for idx, rule in class_rules.head(5).iterrows():  # Top 5 par lift
            antecedents = list(rule['antecedents'])
            consequents = list(rule['consequents'])
            print(f"Si {antecedents} alors {consequents}")
            print(f"  Confiance: {rule['confidence']:.3f}, Lift: {rule['lift']:.3f}")
    else:
        print(f"Aucune règle spécifique pour {classe}")

# 7. Visualisation des résultats
print("\n" + "="*50)
print("VISUALISATION DES RÈGLES")
print("="*50)

import matplotlib.pyplot as plt

plt.figure(figsize=(15, 10))

# Graphique 1: Distribution du support des itemsets
plt.subplot(2, 2, 1)
frequent_itemsets['support'].hist(bins=20, alpha=0.7, color='blue')
plt.title('Distribution du support des itemsets')
plt.xlabel('Support')
plt.ylabel('Fréquence')

# Graphique 2: Top 10 itemsets par support
plt.subplot(2, 2, 2)
top_itemsets = frequent_itemsets.nlargest(10, 'support')
plt.barh(range(len(top_itemsets)), top_itemsets['support'])
plt.yticks(range(len(top_itemsets)), [str(list(x)) for x in top_itemsets['itemsets']], fontsize=8)
plt.title('Top 10 itemsets par support')
plt.xlabel('Support')

# Graphique 3: Relation support-confidence des règles
if len(rules) > 0:
    plt.subplot(2, 2, 3)
    plt.scatter(rules['support'], rules['confidence'], alpha=0.5, c=rules['lift'], cmap='viridis')
    plt.colorbar(label='Lift')
    plt.xlabel('Support')
    plt.ylabel('Confidence')
    plt.title('Support vs Confidence (couleur = Lift)')

# Graphique 4: Distribution du lift
if len(rules) > 0:
    plt.subplot(2, 2, 4)
    rules['lift'].hist(bins=20, alpha=0.7, color='green')
    plt.title('Distribution du lift des règles')
    plt.xlabel('Lift')
    plt.ylabel('Fréquence')

plt.tight_layout()
plt.show()

# 8. Analyse des itemsets les plus intéressants
print("\n" + "="*50)
print("ITEMSETS LES PLUS INTÉRESSANTS")
print("="*50)

# Itemsets de taille 2 avec haut support
itemsets_size2 = frequent_itemsets[frequent_itemsets['length'] == 2]
if len(itemsets_size2) > 0:
    print("Top 5 itemsets de taille 2:")
    for idx, itemset in itemsets_size2.nlargest(5, 'support').iterrows():
        print(f"  {list(itemset['itemsets'])} - Support: {itemset['support']:.3f}")

# Itemsets de taille 3
itemsets_size3 = frequent_itemsets[frequent_itemsets['length'] == 3]
if len(itemsets_size3) > 0:
    print("\nTop 5 itemsets de taille 3:")
    for idx, itemset in itemsets_size3.nlargest(5, 'support').iterrows():
        print(f"  {list(itemset['itemsets'])} - Support: {itemset['support']:.3f}")

# 9. Expérimentation avec différents paramètres
print("\n" + "="*50)
print("EXPÉRIMENTATION AVEC DIFFÉRENTS SUPPORTS")
print("="*50)

supports = [0.1, 0.15, 0.2, 0.25]
for sup in supports:
    freq_items = apriori(df_encoded, min_support=sup, use_colnames=True)
    print(f"Support {sup}: {len(freq_items)} itemsets fréquents")
    
    if len(freq_items) > 0:
        rules_tmp = association_rules(freq_items, metric="confidence", min_threshold=0.5)
        print(f"  → {len(rules_tmp)} règles (confiance ≥ 0.5)")

print("\n" + "="*50)
print("SYNTHÈSE APRIORI - DATASET WINE")
print("="*50)
print("L'algorithme Apriori a permis de découvrir:")
print("1. Les combinaisons de caractéristiques fréquentes dans les vins")
print("2. Les règles d'association entre composants chimiques et classes de vin")
print("3. Les patterns qui distinguent les différentes classes (0, 1, 2)")
print("4. Les relations entre les niveaux des différents composants")
# Out:
# PRÉPARATION DES DONNÉES POUR APRIORI
# ==================================================
# Données après discrétisation :
#    target    alcohol_cat    malic_acid_cat     ash_cat    magnesium_cat  \
# 0       0  alcohol_élevé  malic_acid_moyen   ash_moyen  magnesium_élevé
# 1       0  alcohol_moyen  malic_acid_moyen  ash_faible  magnesium_moyen
# 2       0  alcohol_moyen  malic_acid_moyen   ash_élevé  magnesium_moyen
# 3       0  alcohol_élevé  malic_acid_moyen   ash_élevé  magnesium_élevé
# 4       0  alcohol_moyen  malic_acid_élevé   ash_élevé  magnesium_élevé
#
#      total_phenols_cat    flavanoids_cat target_cat
# 0  total_phenols_élevé  flavanoids_élevé   classe_0
# 1  total_phenols_élevé  flavanoids_élevé   classe_0
# 2  total_phenols_élevé  flavanoids_élevé   classe_0
# 3  total_phenols_élevé  flavanoids_élevé   classe_0
# 4  total_phenols_élevé  flavanoids_élevé   classe_0
#
# Shape: (178, 8)
#
# ==================================================
# CONVERSION EN FORMAT TRANSACTIONS
# ==================================================
# Nombre de transactions: 178
#
# Exemple de transaction (premier vin):
# ['alcohol_élevé', 'malic_acid_moyen', 'ash_moyen', 'magnesium_élevé', 'total_phenols_élevé', 'flavanoids_élevé', 'classe_0']
#
# ==================================================
# ENCODAGE ONE-HOT
# ==================================================
# Shape encodé: (178, 21)
# Nombre d'items: 21
#
# Colonnes (items):
# ['alcohol_faible', 'alcohol_moyen', 'alcohol_élevé', 'ash_faible', 'ash_moyen', 'ash_élevé', 'classe_0', 'classe_1', 'classe_2', 'flavanoids_faible', 'flavanoids_moyen', 'flavanoids_élevé', 'magnesium_faible', 'magnesium_moyen', 'magnesium_élevé', 'malic_acid_faible', 'malic_acid_moyen', 'malic_acid_élevé', 'total_phenols_faible', 'total_phenols_moyen', 'total_phenols_élevé']
#
# ==================================================
# APPLICATION APRIORI
# ==================================================
# Itemsets fréquents (support ≥ 0.2): 43
#
# Top 10 itemsets les plus fréquents:
#      support               itemsets  length
# 7   0.398876             (classe_1)       1
# 3   0.370787           (ash_faible)       1
# 12  0.353933     (magnesium_faible)       1
# 10  0.348315     (flavanoids_moyen)       1
# 0   0.337079       (alcohol_faible)       1
# 15  0.337079    (malic_acid_faible)       1
# 17  0.337079     (malic_acid_élevé)       1
# 20  0.337079  (total_phenols_élevé)       1
# 1   0.331461        (alcohol_moyen)       1
# 2   0.331461        (alcohol_élevé)       1
#
# ==================================================
# RÈGLES D'ASSOCIATION
# ==================================================
# Nombre de règles générées: 57
#
# Top 10 règles par confidence:
# Règle: ['alcohol_faible', 'flavanoids_moyen'] → ['classe_1']
#   Support: 0.219, Confidence: 1.000, Lift: 2.507
#
# Règle: ['classe_2'] → ['flavanoids_faible']
#   Support: 0.264, Confidence: 0.979, Lift: 2.954
#
# Règle: ['total_phenols_faible', 'classe_2'] → ['flavanoids_faible']
#   Support: 0.213, Confidence: 0.974, Lift: 2.940
#
# Règle: ['malic_acid_élevé', 'classe_2'] → ['flavanoids_faible']
#   Support: 0.208, Confidence: 0.974, Lift: 2.938
#
# Règle: ['flavanoids_faible', 'malic_acid_élevé'] → ['classe_2']
#   Support: 0.208, Confidence: 0.949, Lift: 3.518
#
# Règle: ['total_phenols_élevé', 'classe_0'] → ['flavanoids_élevé']
#   Support: 0.225, Confidence: 0.930, Lift: 2.905
#
# Règle: ['alcohol_faible'] → ['classe_1']
#   Support: 0.303, Confidence: 0.900, Lift: 2.256
#
# Règle: ['flavanoids_élevé'] → ['total_phenols_élevé']
#   Support: 0.287, Confidence: 0.895, Lift: 2.654
#
# Règle: ['flavanoids_élevé', 'classe_0'] → ['total_phenols_élevé']
#   Support: 0.225, Confidence: 0.870, Lift: 2.580
#
# Règle: ['total_phenols_élevé'] → ['flavanoids_élevé']
#   Support: 0.287, Confidence: 0.850, Lift: 2.654
#
#
# ==================================================
# ANALYSE PAR CLASSE DE VIN
# ==================================================
#
# --- RÈGLES POUR LA CLASSE_0 ---
# Nombre de règles: 6
# Si ['alcohol_élevé'] alors ['classe_0']
#   Confiance: 0.712, Lift: 2.148
# Si ['flavanoids_élevé'] alors ['classe_0']
#   Confiance: 0.807, Lift: 2.435
# Si ['total_phenols_élevé'] alors ['classe_0']
#   Confiance: 0.717, Lift: 2.162
# Si ['flavanoids_élevé', 'total_phenols_élevé'] alors ['classe_0']
#   Confiance: 0.784, Lift: 2.366
# Si ['flavanoids_élevé'] alors ['total_phenols_élevé', 'classe_0']
#   Confiance: 0.702, Lift: 2.905
#
# --- RÈGLES POUR LA CLASSE_1 ---
# Nombre de règles: 8
# Si ['alcohol_faible'] alors ['classe_1']
#   Confiance: 0.900, Lift: 2.256
# Si ['ash_faible'] alors ['classe_1']
#   Confiance: 0.621, Lift: 1.557
# Si ['flavanoids_moyen'] alors ['classe_1']
#   Confiance: 0.774, Lift: 1.941
# Si ['magnesium_faible'] alors ['classe_1']
#   Confiance: 0.683, Lift: 1.711
# Si ['malic_acid_faible'] alors ['classe_1']
#   Confiance: 0.667, Lift: 1.671
#
# --- RÈGLES POUR LA CLASSE_2 ---
# Nombre de règles: 9
# Si ['flavanoids_faible'] alors ['classe_2']
#   Confiance: 0.797, Lift: 2.954
# Si ['malic_acid_élevé'] alors ['classe_2']
#   Confiance: 0.633, Lift: 2.349
# Si ['total_phenols_faible'] alors ['classe_2']
#   Confiance: 0.661, Lift: 2.451
# Si ['flavanoids_faible', 'malic_acid_élevé'] alors ['classe_2']
#   Confiance: 0.949, Lift: 3.518
# Si ['malic_acid_élevé'] alors ['flavanoids_faible', 'classe_2']
#   Confiance: 0.617, Lift: 2.335
#
# ==================================================
# VISUALISATION DES RÈGLES
# ==================================================
# ==================================================
# ITEMSETS LES PLUS INTÉRESSANTS
# ==================================================
# Top 5 itemsets de taille 2:
#   ['alcohol_faible', 'classe_1'] - Support: 0.303
#   ['flavanoids_élevé', 'total_phenols_élevé'] - Support: 0.287
#   ['flavanoids_moyen', 'classe_1'] - Support: 0.270
#   ['flavanoids_faible', 'classe_2'] - Support: 0.264
#   ['flavanoids_élevé', 'classe_0'] - Support: 0.258
#
# Top 5 itemsets de taille 3:
#   ['flavanoids_élevé', 'total_phenols_élevé', 'classe_0'] - Support: 0.225
#   ['flavanoids_moyen', 'alcohol_faible', 'classe_1'] - Support: 0.219
#   ['total_phenols_faible', 'flavanoids_faible', 'classe_2'] - Support: 0.213
#   ['malic_acid_élevé', 'flavanoids_faible', 'classe_2'] - Support: 0.208
#
# ==================================================
# EXPÉRIMENTATION AVEC DIFFÉRENTS SUPPORTS
# ==================================================
# Support 0.1: 211 itemsets fréquents
#   → 619 règles (confiance ≥ 0.5)
# Support 0.15: 93 itemsets fréquents
#   → 224 règles (confiance ≥ 0.5)
# Support 0.2: 43 itemsets fréquents
#   → 60 règles (confiance ≥ 0.5)
# Support 0.25: 27 itemsets fréquents
#   → 12 règles (confiance ≥ 0.5)
#
# ==================================================
# SYNTHÈSE APRIORI - DATASET WINE
# ==================================================
# L'algorithme Apriori a permis de découvrir:
# 1. Les combinaisons de caractéristiques fréquentes dans les vins
# 2. Les règles d'association entre composants chimiques et classes de vin
# 3. Les patterns qui distinguent les différentes classes (0, 1, 2)
# 4. Les relations entre les niveaux des différents composants

# %% [markdown]
# ### APPLICATION DE MIN-APRIORI A WINE

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from itertools import combinations
import math

# Charger le dataset Wine et convertir en format "documents"
data = load_wine()
df = pd.DataFrame(data.data, columns=data.feature_names)
df['target'] = data.target

print("Dataset Wine chargé")
print(f"Shape: {df.shape}")

# 1. Conversion des données numériques en format texte pour TF-IDF
print("\n" + "="*50)
print("CONVERSION EN FORMAT TEXTE")
print("="*50)

def create_documents_from_wine(df, feature_names):
    """
    Convertit les données numériques en documents texte
    Chaque caractéristique est discrétisée et traitée comme un "mot"
    """
    documents = []
    
    for idx, row in df.iterrows():
        doc_terms = []
        for feature in feature_names:
            value = row[feature]
            # Discrétiser la valeur en 3 catégories
            if value < df[feature].quantile(0.33):
                term = f"{feature}_faible"
            elif value < df[feature].quantile(0.66):
                term = f"{feature}_moyen"
            else:
                term = f"{feature}_élevé"
            doc_terms.append(term)
        
        # Ajouter aussi la classe comme terme
        doc_terms.append(f"classe_{int(row['target'])}")
        documents.append(" ".join(doc_terms))
    
    return documents

# Créer les documents
feature_names = ['alcohol', 'malic_acid', 'ash', 'magnesium', 'total_phenols', 'flavanoids']
documents = create_documents_from_wine(df, feature_names)

print(f"Nombre de documents: {len(documents)}")
print("\nExemple de document (premier vin):")
print(documents[0])

# 2. Calcul de la matrice TF-IDF
print("\n" + "="*50)
print("CALCUL TF-IDF")
print("="*50)

vectorizer = TfidfVectorizer()
tfidf_matrix = vectorizer.fit_transform(documents)
feature_names_tfidf = vectorizer.get_feature_names_out()

# Convertir en DataFrame pour plus de lisibilité
tfidf_df = pd.DataFrame(tfidf_matrix.toarray(), columns=feature_names_tfidf)

print(f"Shape de la matrice TF-IDF: {tfidf_matrix.shape}")
print(f"Nombre de termes (mots): {len(feature_names_tfidf)}")
print("\nTop 10 termes les plus fréquents:")
print(tfidf_df.sum().sort_values(ascending=False).head(10))

# 3. Implémentation de Min-Apriori
print("\n" + "="*50)
print("IMPLÉMENTATION MIN-APRIORI")
print("="*50)

class MinApriori:
    def __init__(self, min_support=0.1):
        self.min_support = min_support
    
    def compute_support(self, itemset, tfidf_matrix):
        """
        Calcule le support Min-Apriori pour un itemset
        support(itemset) = sum over all documents of min(TF-IDF des termes dans l'itemset)
        """
        if len(itemset) == 0:
            return 0.0
        
        # Obtenir les indices des termes dans la matrice
        term_indices = [self.term_to_index[term] for term in itemset]
        
        # Pour chaque document, prendre le minimum des TF-IDF des termes de l'itemset
        min_values = []
        for doc_idx in range(tfidf_matrix.shape[0]):
            term_values = [tfidf_matrix[doc_idx, term_idx] for term_idx in term_indices]
            min_val = min(term_values) if term_values else 0.0
            min_values.append(min_val)
        
        return sum(min_values)
    
    def fit(self, tfidf_matrix, feature_names):
        self.tfidf_matrix = tfidf_matrix
        self.feature_names = feature_names
        self.term_to_index = {term: idx for idx, term in enumerate(feature_names)}
        
        # Étape 1: Itemsets de taille 1
        frequent_1_itemsets = {}
        for term in feature_names:
            itemset = frozenset([term])
            support = self.compute_support(itemset, tfidf_matrix)
            if support >= self.min_support:
                frequent_1_itemsets[itemset] = support
        
        self.frequent_itemsets = frequent_1_itemsets
        print(f"Itemsets de taille 1: {len(frequent_1_itemsets)}")
        
        # Étape 2: Générer les itemsets de taille k
        k = 2
        while True:
            candidate_itemsets = self._generate_candidates(k)
            if not candidate_itemsets:
                break
            
            frequent_k_itemsets = {}
            for itemset in candidate_itemsets:
                support = self.compute_support(itemset, tfidf_matrix)
                if support >= self.min_support:
                    frequent_k_itemsets[itemset] = support
            
            if not frequent_k_itemsets:
                break
            
            print(f"Itemsets de taille {k}: {len(frequent_k_itemsets)}")
            self.frequent_itemsets.update(frequent_k_itemsets)
            k += 1
        
        return self
    
    def _generate_candidates(self, k):
        """Génère les candidats de taille k à partir des itemsets de taille k-1"""
        if k == 2:
            # Combinaisons des itemsets de taille 1
            items = [list(itemset)[0] for itemset in self.frequent_itemsets.keys() if len(itemset) == 1]
            return [frozenset([i, j]) for i, j in combinations(items, 2)]
        else:
            # Pour k>2, utiliser la propriété Apriori
            candidates = set()
            itemsets_k_minus_1 = [itemset for itemset in self.frequent_itemsets.keys() if len(itemset) == k-1]
            
            for i in range(len(itemsets_k_minus_1)):
                for j in range(i+1, len(itemsets_k_minus_1)):
                    itemset1 = itemsets_k_minus_1[i]
                    itemset2 = itemsets_k_minus_1[j]
                    
                    # Vérifier si les k-2 premiers éléments sont identiques
                    list1 = sorted(list(itemset1))
                    list2 = sorted(list(itemset2))
                    
                    if list1[:-1] == list2[:-1]:
                        new_itemset = frozenset(list1 + [list2[-1]])
                        candidates.add(new_itemset)
            
            return list(candidates)
    
    def get_rules(self, min_confidence=0.5):
        """Génère les règles d'association (simplifié)"""
        rules = []
        for itemset in self.frequent_itemsets.keys():
            if len(itemset) >= 2:
                itemset_list = list(itemset)
                # Générer toutes les règles possibles
                for i in range(1, len(itemset_list)):
                    for antecedent in combinations(itemset_list, i):
                        antecedent = frozenset(antecedent)
                        consequent = frozenset(itemset_list) - antecedent
                        
                        if antecedent in self.frequent_itemsets and consequent in self.frequent_itemsets:
                            confidence = self.frequent_itemsets[itemset] / self.frequent_itemsets[antecedent]
                            if confidence >= min_confidence:
                                rules.append({
                                    'antecedent': antecedent,
                                    'consequent': consequent,
                                    'support': self.frequent_itemsets[itemset],
                                    'confidence': confidence
                                })
        return rules

# 4. Application de Min-Apriori
print("\nAPPLICATION DE MIN-APRIORI")
min_apriori = MinApriori(min_support=0.05)
min_apriori.fit(tfidf_matrix, feature_names_tfidf)

print(f"\nTotal d'itemsets fréquents trouvés: {len(min_apriori.frequent_itemsets)}")

# 5. Affichage des résultats
print("\n" + "="*50)
print("RÉSULTATS MIN-APRIORI")
print("="*50)

# Itemsets de taille 1
print("\nTOP 10 ITEMSETS DE TAILLE 1:")
itemsets_1 = {k: v for k, v in min_apriori.frequent_itemsets.items() if len(k) == 1}
for itemset, support in sorted(itemsets_1.items(), key=lambda x: x[1], reverse=True)[:10]:
    print(f"  {list(itemset)[0]}: support = {support:.4f}")

# Itemsets de taille 2
print("\nTOP 10 ITEMSETS DE TAILLE 2:")
itemsets_2 = {k: v for k, v in min_apriori.frequent_itemsets.items() if len(k) == 2}
for itemset, support in sorted(itemsets_2.items(), key=lambda x: x[1], reverse=True)[:10]:
    terms = list(itemset)
    print(f"  {terms[0]} + {terms[1]}: support = {support:.4f}")

# Itemsets de taille 3
print("\nITEMSETS DE TAILLE 3:")
itemsets_3 = {k: v for k, v in min_apriori.frequent_itemsets.items() if len(k) == 3}
for itemset, support in sorted(itemsets_3.items(), key=lambda x: x[1], reverse=True)[:5]:
    terms = list(itemset)
    print(f"  {terms}: support = {support:.4f}")

# 6. Génération des règles
print("\n" + "="*50)
print("RÈGLES D'ASSOCIATION")
print("="*50)

rules = min_apriori.get_rules(min_confidence=0.6)
print(f"Nombre de règles générées: {len(rules)}")

if rules:
    print("\nTOP 10 RÈGLES PAR CONFIDENCE:")
    for rule in sorted(rules, key=lambda x: x['confidence'], reverse=True)[:10]:
        ant = list(rule['antecedent'])
        cons = list(rule['consequent'])
        print(f"  {ant} → {cons}")
        print(f"    Support: {rule['support']:.4f}, Confidence: {rule['confidence']:.4f}")

# 7. Analyse des associations avec les classes
print("\n" + "="*50)
print("ASSOCIATIONS AVEC LES CLASSES DE VIN")
print("="*50)

class_terms = [term for term in feature_names_tfidf if term.startswith('classe_')]
print("Termes de classe:", class_terms)

for class_term in class_terms:
    print(f"\n--- ASSOCIATIONS POUR {class_term.upper()} ---")
    class_associations = []
    
    for itemset, support in min_apriori.frequent_itemsets.items():
        if class_term in itemset and len(itemset) > 1:
            other_terms = [term for term in itemset if term != class_term]
            class_associations.append((other_terms, support))
    
    # Trier par support
    class_associations.sort(key=lambda x: x[1], reverse=True)
    
    for terms, support in class_associations[:5]:
        print(f"  {terms} → support = {support:.4f}")

# 8. Visualisation
print("\n" + "="*50)
print("VISUALISATION")
print("="*50)

import matplotlib.pyplot as plt

# Distribution des supports
supports = list(min_apriori.frequent_itemsets.values())
plt.figure(figsize=(12, 4))

plt.subplot(1, 2, 1)
plt.hist(supports, bins=20, alpha=0.7, color='lightblue', edgecolor='black')
plt.title('Distribution des supports Min-Apriori')
plt.xlabel('Support')
plt.ylabel('Fréquence')

# Top itemsets par taille
plt.subplot(1, 2, 2)
sizes = [len(itemset) for itemset in min_apriori.frequent_itemsets.keys()]
plt.hist(sizes, bins=range(1, max(sizes)+2), alpha=0.7, color='lightgreen', edgecolor='black')
plt.title('Distribution de la taille des itemsets')
plt.xlabel('Taille des itemsets')
plt.ylabel('Fréquence')

plt.tight_layout()
plt.show()

print("\n" + "="*50)
print("SYNTHÈSE MIN-APRIORI")
print("="*50)
print("L'algorithme Min-Apriori a permis de découvrir:")
print("1. Les combinaisons de caractéristiques fréquentes basées sur TF-IDF")
print("2. Les associations entre niveaux de composants chimiques")
print("3. Les patterns spécifiques à chaque classe de vin")
print("4. Les relations basées sur la co-occurrence minimale dans les documents")
# Out:
# Dataset Wine chargé
# Shape: (178, 14)
#
# ==================================================
# CONVERSION EN FORMAT TEXTE
# ==================================================
# Nombre de documents: 178
#
# Exemple de document (premier vin):
# alcohol_élevé malic_acid_moyen ash_moyen magnesium_élevé total_phenols_élevé flavanoids_élevé classe_0
#
# ==================================================
# CALCUL TF-IDF
# ==================================================
# Shape de la matrice TF-IDF: (178, 21)
# Nombre de termes (mots): 21
#
# Top 10 termes les plus fréquents:
# classe_1               24.715570
# total_phenols_élevé    23.997164
# magnesium_élevé        23.076345
# flavanoids_élevé       23.034765
# malic_acid_moyen       22.927587
# alcohol_élevé          22.850581
# ash_élevé              22.796894
# malic_acid_élevé       22.626190
# classe_0               22.523853
# alcohol_faible         22.442477
# dtype: float64
#
# ==================================================
# IMPLÉMENTATION MIN-APRIORI
# ==================================================
#
# APPLICATION DE MIN-APRIORI
# Itemsets de taille 1: 21
# Itemsets de taille 2: 184
# Itemsets de taille 3: 830
# Itemsets de taille 4: 1724
# Itemsets de taille 5: 1616
# Itemsets de taille 6: 716
# Itemsets de taille 7: 124
#
# Total d'itemsets fréquents trouvés: 5215
#
# ==================================================
# RÉSULTATS MIN-APRIORI
# ==================================================
#
# TOP 10 ITEMSETS DE TAILLE 1:
#   classe_1: support = 24.7156
#   total_phenols_élevé: support = 23.9972
#   magnesium_élevé: support = 23.0763
#   flavanoids_élevé: support = 23.0348
#   malic_acid_moyen: support = 22.9276
#   alcohol_élevé: support = 22.8506
#   ash_élevé: support = 22.7969
#   malic_acid_élevé: support = 22.6262
#   classe_0: support = 22.5239
#   alcohol_faible: support = 22.4425
#
# TOP 10 ITEMSETS DE TAILLE 2:
#   flavanoids_élevé + total_phenols_élevé: support = 20.7372
#   alcohol_faible + classe_1: support = 18.4490
#   flavanoids_élevé + classe_0: support = 17.7202
#   flavanoids_faible + classe_2: support = 17.5446
#   total_phenols_faible + flavanoids_faible: support = 17.2523
#   total_phenols_élevé + classe_0: support = 17.0692
#   classe_0 + alcohol_élevé: support = 16.1944
#   flavanoids_moyen + classe_1: support = 15.6147
#   flavanoids_faible + malic_acid_élevé: support = 14.7216
#   total_phenols_faible + classe_2: support = 14.5695
#
# ITEMSETS DE TAILLE 3:
#   ['flavanoids_élevé', 'total_phenols_élevé', 'classe_0']: support = 15.9823
#   ['total_phenols_faible', 'flavanoids_faible', 'classe_2']: support = 14.1937
#   ['malic_acid_élevé', 'flavanoids_faible', 'classe_2']: support = 13.9664
#   ['flavanoids_élevé', 'classe_0', 'alcohol_élevé']: support = 13.9598
#   ['total_phenols_élevé', 'classe_0', 'alcohol_élevé']: support = 13.4450
#
# ==================================================
# RÈGLES D'ASSOCIATION
# ==================================================
# Nombre de règles générées: 17703
#
# TOP 10 RÈGLES PAR CONFIDENCE:
#   ['ash_faible', 'classe_2'] → ['flavanoids_faible']
#     Support: 3.3558, Confidence: 1.0000
#   ['total_phenols_élevé', 'classe_2'] → ['malic_acid_moyen']
#     Support: 0.7149, Confidence: 1.0000
#   ['flavanoids_faible', 'alcohol_élevé'] → ['classe_2']
#     Support: 5.1585, Confidence: 1.0000
#   ['total_phenols_élevé', 'flavanoids_faible'] → ['alcohol_élevé']
#     Support: 0.7149, Confidence: 1.0000
#   ['total_phenols_élevé', 'classe_2'] → ['alcohol_élevé']
#     Support: 0.7149, Confidence: 1.0000
#   ['total_phenols_élevé', 'classe_2'] → ['ash_élevé']
#     Support: 0.7149, Confidence: 1.0000
#   ['alcohol_faible', 'classe_2'] → ['flavanoids_faible']
#     Support: 2.2330, Confidence: 1.0000
#   ['alcohol_élevé', 'classe_1'] → ['malic_acid_faible']
#     Support: 1.0459, Confidence: 1.0000
#   ['total_phenols_élevé', 'flavanoids_faible'] → ['ash_élevé']
#     Support: 0.7149, Confidence: 1.0000
#   ['total_phenols_élevé', 'flavanoids_faible'] → ['classe_2']
#     Support: 0.7149, Confidence: 1.0000
#
# ==================================================
# ASSOCIATIONS AVEC LES CLASSES DE VIN
# ==================================================
# Termes de classe: ['classe_0', 'classe_1', 'classe_2']
#
# --- ASSOCIATIONS POUR CLASSE_0 ---
#   ['flavanoids_élevé'] → support = 17.7202
#   ['total_phenols_élevé'] → support = 17.0692
#   ['alcohol_élevé'] → support = 16.1944
#   ['flavanoids_élevé', 'total_phenols_élevé'] → support = 15.9823
#   ['flavanoids_élevé', 'alcohol_élevé'] → support = 13.9598
#
# --- ASSOCIATIONS POUR CLASSE_1 ---
#   ['alcohol_faible'] → support = 18.4490
#   ['flavanoids_moyen'] → support = 15.6147
#   ['magnesium_faible'] → support = 14.2540
#   ['ash_faible'] → support = 13.2104
#   ['malic_acid_faible'] → support = 13.1791
#
# --- ASSOCIATIONS POUR CLASSE_2 ---
#   ['flavanoids_faible'] → support = 17.5446
#   ['total_phenols_faible'] → support = 14.5695
#   ['malic_acid_élevé'] → support = 14.3363
#   ['total_phenols_faible', 'flavanoids_faible'] → support = 14.1937
#   ['malic_acid_élevé', 'flavanoids_faible'] → support = 13.9664
#
# ==================================================
# VISUALISATION
# ==================================================
# ==================================================
# SYNTHÈSE MIN-APRIORI
# ==================================================
# L'algorithme Min-Apriori a permis de découvrir:
# 1. Les combinaisons de caractéristiques fréquentes basées sur TF-IDF
# 2. Les associations entre niveaux de composants chimiques
# 3. Les patterns spécifiques à chaque classe de vin
# 4. Les relations basées sur la co-occurrence minimale dans les documents
